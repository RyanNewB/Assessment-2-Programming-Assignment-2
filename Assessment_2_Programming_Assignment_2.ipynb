# %% [markdown]
# <a href="https://colab.research.google.com/github/RyanNewB/Assessment-2-Programming-Assignment-2/blob/main/Assessment_2_Programming_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Compute and visualize the total energy consumption for each state.**

# %% [markdown]
# First is to import the data and  establish the connection provided for this case using "import" function below:

# %%
import sqlite3
connection = sqlite3.connect('AUS_energy_sqlite3.db')
cursor = connection.cursor()

# %% [markdown]
# Second, is

# %%
sql='''
SELECT name FROM sqlite_master WHERE type='table';
'''
cursor.execute(sql)
cursor.fetchall()
# Out:
# [('AUS_energy',)]

# %%
sql='''
PRAGMA table_info('your_table');
'''
cursor.execute(sql)
cursor.fetchall()
# Out:
# []

# %%
import pandas as pd

sql='''
SELECT * from AUS_energy;
'''
# Load the data into a DataFrame
AUS_energy_df = pd.read_sql_query(sql, connection)

# %%
AUS_energy_df.head()
# Out:
#       Year State Coal (PJ)  Oil (PJ)  Gas (PJ)  Renewables (PJ)  Population  \
# 0  2008-09    WA     132.9     294.3     474.7             15.6     2240250
# 1  2008-09   NSW     800.9     587.5     131.6             54.7     7408540
# 2  2008-09   VIC     695.3     432.9     273.5             33.6     5371934
# 3  2008-09   QLD     629.2     469.5     187.9             77.4     4328771
# 4  2008-09    SA      80.2     120.2     134.0             21.2     1608902
#
#    GSP ($ million)
# 0           244695
# 1           530532
# 2           368579
# 3           284526
# 4           100174

# %%
# @title Oil (PJ)

from matplotlib import pyplot as plt
AUS_energy_df['Oil (PJ)'].plot(kind='hist', bins=20, title='Oil (PJ)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
AUS_energy_df.tail()
# Out:
#        Year State Coal (PJ)  Oil (PJ)  Gas (PJ)  Renewables (PJ)  Population  \
# 93  2021-22   VIC     410.7     410.0     237.5            105.2     6625964
# 94  2021-22   QLD     485.6     504.7     305.7            143.0     5320496
# 95  2021-22    SA      25.9     141.6      80.2             48.3     1821200
# 96  2021-22   TAS       8.8      39.9       7.1             48.1      571013
# 97  2021-22    NT                37.6     110.6              1.6      250219
#
#     GSP ($ million)
# 93           500900
# 94           384508
# 95           124252
# 96            36701
# 97            26058

# %%
AUS_energy_df
# Out:
#        Year State Coal (PJ)  Oil (PJ)  Gas (PJ)  Renewables (PJ)  Population  \
# 0   2008-09    WA     132.9     294.3     474.7             15.6     2240250
# 1   2008-09   NSW     800.9     587.5     131.6             54.7     7408540
# 2   2008-09   VIC     695.3     432.9     273.5             33.6     5371934
# 3   2008-09   QLD     629.2     469.5     187.9             77.4     4328771
# 4   2008-09    SA      80.2     120.2     134.0             21.2     1608902
# ..      ...   ...       ...       ...       ...              ...         ...
# 93  2021-22   VIC     410.7     410.0     237.5            105.2     6625964
# 94  2021-22   QLD     485.6     504.7     305.7            143.0     5320496
# 95  2021-22    SA      25.9     141.6      80.2             48.3     1821200
# 96  2021-22   TAS       8.8      39.9       7.1             48.1      571013
# 97  2021-22    NT                37.6     110.6              1.6      250219
#
#     GSP ($ million)
# 0            244695
# 1            530532
# 2            368579
# 3            284526
# 4            100174
# ..              ...
# 93           500900
# 94           384508
# 95           124252
# 96            36701
# 97            26058
#
# [98 rows x 8 columns]

# %%
AUS_energy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             98 non-null     object
#  1   State            98 non-null     object
#  2   Coal (PJ)        98 non-null     object
#  3   Oil (PJ)         98 non-null     float64
#  4   Gas (PJ)         98 non-null     float64
#  5   Renewables (PJ)  98 non-null     float64
#  6   Population       98 non-null     int64
#  7   GSP ($ million)  98 non-null     int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 6.2+ KB

# %%
AUS_energy_df.describe()
# Out:
#          Oil (PJ)    Gas (PJ)  Renewables (PJ)    Population  GSP ($ million)
# count   98.000000   98.000000        98.000000  9.800000e+01        98.000000
# mean   317.653061  204.587755        51.580612  3.424330e+06    266337.000000
# std    229.318224  179.205651        38.383143  2.769970e+06    209376.485897
# min     33.400000    6.600000         0.400000  2.260270e+05     19469.000000
# 25%     54.350000   81.675000        24.025000  5.502752e+05     33440.000000
# 50%    379.100000  144.700000        42.500000  2.548325e+06    301927.000000
# 75%    507.675000  263.600000        72.600000  5.622772e+06    390060.250000
# max    687.400000  692.600000       143.000000  8.622575e+06    706003.000000

# %%
AUS_energy_df[['State', 'GSP ($ million)']]
# Out:
#    State  GSP ($ million)
# 0     WA           244695
# 1    NSW           530532
# 2    VIC           368579
# 3    QLD           284526
# 4     SA           100174
# ..   ...              ...
# 93   VIC           500900
# 94   QLD           384508
# 95    SA           124252
# 96   TAS            36701
# 97    NT            26058
#
# [98 rows x 2 columns]
